# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s:%(filename)s:%(message)s')
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# import all model concepts
from src.model import *

# import the simulator
from src.simulator.simulator import Simulator

# import a library that can visualise our systems
from src.ui import elk
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
class Resources(object):
    on_off = Resource("switch", ["on", "off"])
    flow = Resource("L/min", REAL)
    water = Resource("Liters", REAL)

# %%
class Pump(Entity):
    """
    A pump that is placed in an assumingly infinite source of water 
    (like a big water tank or lake), 
    we therefore don't model the pump's water input.
    
    For this example we also disregard the electricity that is required for the pump to operate.
    """
    switch = Input(resource=Resources.on_off, value="on")
    output = Output(resource=Resources.flow, value=0)
    
    on = State()
    off = current = State()
    
    # transitions and guards (as lambdas)
    off_to_on = Transition(source=off, target=on, guard=(lambda self: self.switch.value == "on"))
    on_to_off = Transition(source=on, target=off, guard=(lambda self: self.switch.value == "off"))
    
    # update functions are related to a state and define the value of a port
    @update(state=on, target=output)
    def set_on(self, dt=0):
        return 1.5

    @update(state=off, target=output)
    def set_off(self, dt=0):
        return 0

elk.plot(Pump())
# Out:
#     <iframe id="iframe_0b025e85-6f0d-435e-b877-18e7f523c409" style="border:none;" width="100%" height="25px" id="map" srcdoc="
#     <html>
# <head>
#     <!-- CSS Spinning loading dial -->
#     <style>
#         .loader {
#           margin: 16px;
#           border: 16px solid #f3f3f3;
#           border-radius: 50%;
#           border-top: 16px solid blue;
#           border-bottom: 16px solid blue;
#           /* border-right: 32px solid green;
#           border-bottom: 32px solid red;
#           border-left: 32px solid yellow; */
#           width: 64px;
#           height: 64px;
#           -webkit-animation: spin 2s linear infinite;
#           animation: spin 2s linear infinite;
#         }
#
#         @-webkit-keyframes spin {
#           0% { -webkit-transform: rotate(0deg); }
#           100% { -webkit-transform: rotate(360deg); }
#         }
#
#         @keyframes spin {
#           0% { transform: rotate(0deg); }
#           100% { transform: rotate(360deg); }
#         }
#     </style>
#
#     <style>
#         body,html{
#             margin:0px;
#             padding:0px;
#         }
#
#         #growWindow {
#             position: absolute;
#             bottom: 0px;
#             height: 20px;
#             width: 100%;
#             text-align: center;
#             background-color: lightgray;
#             cursor: pointer;
#         }
#
#         i {
#             border: solid black;
#             border-width: 0 3px 3px 0;
#             display: inline-block;
#             padding: 3px;
#         }
#
#         .down {
#             transform: rotate(45deg);
#             -webkit-transform: rotate(45deg);
#         }
#     </style>
#
#     <script>
#         const iframe = window.parent.document.getElementById('iframe_0b025e85-6f0d-435e-b877-18e7f523c409');
#         function growIframe(){
#             var height = iframe.offsetHeight;
#             iframe.setAttribute('style', 'height:'+ (height+100) +'px');
#         }
#     </script>
#
#     <script
#   src=&quot;https://code.jquery.com/jquery-3.3.1.slim.min.js&quot;
#   integrity=&quot;sha256-3edrmyuQ0w65f8gfBsqowzjJe2iM6n0nKciPUp8y+7E=&quot;
#   crossorigin=&quot;anonymous&quot;></script>
#
#     <!-- code highlight -->
#     <link rel=&quot;stylesheet&quot; type=&quot;text/css&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/styles/vs.min.css&quot; />
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/highlight.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/languages/python.min.js&quot;></script>
#     <!-- <script>hljs.initHighlightingOnLoad();</script> -->
#
#     <!-- Sets the basepath for the library if not in same directory -->
#     <script type='text/javascript'>mxBasePath = './mxgraph/javascript/src'</script>
#     <!-- Loads and initializes the library -->
#     <script type='text/javascript' src='./mxgraph/javascript/src/js/mxClient.js'></script>
#
#     <!-- ELK-JS -->
#     <script type='text/javascript' src='https://cdn.jsdelivr.net/npm/elkjs@0.3.0/lib/elk.bundled.js'></script>
#
#     <!-- import plotting JS -->
#     <script type='text/javascript' src='./src/ui/mxgraphCustom.js'></script>
#     <script type='text/javascript'>
#         main = function(){
#             elkgraph = {'id': 'root', 'label': {'label': '', 'text': ''}, 'children': [{'id': '139859538649328', 'label': {'label': ' | Pump', 'text': ''}, 'children': [{'id': '139859538650112', 'label': {'label': 'off'}, 'width': 75, 'height': 75, 'cresttype': 'state', 'currentstate': 1}, {'id': '139859538650280', 'label': {'label': 'on'}, 'width': 75, 'height': 75, 'cresttype': 'state', 'currentstate': 0}, {'id': '139859538650224_mid', 'label': {'label': '', 'text': '<h3>off_to_on</h3><p>midpoint</p>'}, 'width': 1, 'height': 1, 'cresttype': 'midpoint'}, {'id': '139859538650336_mid', 'label': {'label': '', 'text': '<h3>on_to_off</h3><p>midpoint</p>'}, 'width': 1, 'height': 1, 'cresttype': 'midpoint'}], 'ports': [{'id': '139859538650056', 'label': {'label': 'switch<br />on (switch)', 'text': '<h3>switch</h3><p>on (switch)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'input'}, {'id': '139859538650000', 'label': {'label': 'output<br />0 (L/min)', 'text': '<h3>output</h3><p>0 (L/min)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'output'}], 'edges': [{'id': '139859538650224', 'label': {'label': 'off_to_on', 'text': '<h3>off_to_on</h3><h4>from state off --> to state on</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>off_to_on = Transition(source=off, target=on, guard=(lambda self: self.switch.value == &quot;on&quot;))\n</code></pre>'}, 'sources': ['139859538650112'], 'targets': ['139859538650280'], 'cresttype': 'transition'}, {'id': '139859538650336', 'label': {'label': 'on_to_off', 'text': '<h3>on_to_off</h3><h4>from state on --> to state off</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>on_to_off = Transition(source=on, target=off, guard=(lambda self: self.switch.value == &quot;off&quot;))\n</code></pre>'}, 'sources': ['139859538650280'], 'targets': ['139859538650112'], 'cresttype': 'transition'}, {'id': '139859538650168', 'label': {'label': 'set_off', 'text': '<h3>set_off</h3><h4>state off --> writes port .output</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>@update(state=off, target=output)\ndef set_off(self, dt=0):\n    return 0\n</code></pre>'}, 'sources': ['139859538650112'], 'targets': ['139859538650000'], 'cresttype': 'update'}, {'id': '139859538650392', 'label': {'label': 'set_on', 'text': '<h3>set_on</h3><h4>state on --> writes port .output</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>@update(state=on, target=output)\ndef set_on(self, dt=0):\n    return 1.5\n</code></pre>'}, 'sources': ['139859538650280'], 'targets': ['139859538650000'], 'cresttype': 'update'}], 'cresttype': 'entity', 'width': 300, 'height': 200}], 'edges': [], 'cresttype': 'root'};
#             mxgraph_main(elkgraph);  // trigger drawing
#         };
#     </script>
# </head>
# <body onload='main()'>
#     <!-- Creates a container for the graph with a grid wallpaper -->
#     <div id='graphContainer' style='position:relative;overflow:hidden;width:100%;height:25px;cursor:default;'>
#         <!-- <div id='loader' class='loader'></div> -->
#     </div>
#     <div id='growWindow' onclick='growIframe()'> <i class='arrow down'></i> </div>
# </body>
# </html>
#
#     " />

# %%
class Tank(Entity):
    inflow = Input(resource=Resources.flow, value=1)  # the current inflow
    outflow = Output(resource=Resources.flow, value=0)  # the current outflow
    spill = Output(resource=Resources.water, value=0)  # the amount of water spilt
    quantity = Output(resource=Resources.water, value=0)  # the volume of water that left the tank
    
    maxoutflow = Local(resource=Resources.flow, value=0.05) # the maximum outflow
    volume = Local(resource=Resources.water, value=1.5)  # the currently held water
    capacity = Local(resource=Resources.water, value=1.5)  # the maximum capacity
        
    """ States """
    full = State()
    partially = current = State()
    empty = State()
        
    """ Transitions """
    @transition(source=partially, target=full)
    def to_full(self):
        return self.volume.value >= self.capacity.value
    
    @transition(source=partially, target=empty)
    def to_empty(self):
        return self.volume.value <= 0
    
    @transition(source=[empty,full], target=partially)
    def to_partially(self):
        return 0 < self.volume.value and self.volume.value < self.capacity.value
    
    """ Updates """
    @update(state=[empty,partially,full], target=volume)
    def set_volume(self, dt):
        netflow = self.inflow.value - self.outflow.value
        theoretical = self.volume.value + netflow * dt
        if theoretical >= self.capacity.value:
            return self.capacity.value
        else:
            return theoretical
        
    @update(state=[partially,full], target=outflow)
    def set_outflow_nonempty(self, dt):
        return self.maxoutflow.value
    
    @update(state=empty, target=outflow)
    def set_outflow_empty(self, dt):
        if self.inflow.value > self.maxoutflow.value:
            return self.maxoutflow.value
        else:
            return self.inflow.value
        
    @update(state=[empty,partially,full], target=quantity)
    def increase_quantity(self, dt):
        return self.quantity.value + self.outflow.value * dt
    
    @update(state=full, target=spill)
    def increase_spill(self, dt):
        netflow = self.inflow.value - self.outflow.value
        if netflow > 0:
            return self.spill.value + netflow * dt
        else:
            return self.spill.value
    
elk.plot(Tank())
# Out:
#     <iframe id="iframe_dccaa42d-0496-406d-9c73-d2d83c98f2bb" style="border:none;" width="100%" height="25px" id="map" srcdoc="
#     <html>
# <head>
#     <!-- CSS Spinning loading dial -->
#     <style>
#         .loader {
#           margin: 16px;
#           border: 16px solid #f3f3f3;
#           border-radius: 50%;
#           border-top: 16px solid blue;
#           border-bottom: 16px solid blue;
#           /* border-right: 32px solid green;
#           border-bottom: 32px solid red;
#           border-left: 32px solid yellow; */
#           width: 64px;
#           height: 64px;
#           -webkit-animation: spin 2s linear infinite;
#           animation: spin 2s linear infinite;
#         }
#
#         @-webkit-keyframes spin {
#           0% { -webkit-transform: rotate(0deg); }
#           100% { -webkit-transform: rotate(360deg); }
#         }
#
#         @keyframes spin {
#           0% { transform: rotate(0deg); }
#           100% { transform: rotate(360deg); }
#         }
#     </style>
#
#     <style>
#         body,html{
#             margin:0px;
#             padding:0px;
#         }
#
#         #growWindow {
#             position: absolute;
#             bottom: 0px;
#             height: 20px;
#             width: 100%;
#             text-align: center;
#             background-color: lightgray;
#             cursor: pointer;
#         }
#
#         i {
#             border: solid black;
#             border-width: 0 3px 3px 0;
#             display: inline-block;
#             padding: 3px;
#         }
#
#         .down {
#             transform: rotate(45deg);
#             -webkit-transform: rotate(45deg);
#         }
#     </style>
#
#     <script>
#         const iframe = window.parent.document.getElementById('iframe_dccaa42d-0496-406d-9c73-d2d83c98f2bb');
#         function growIframe(){
#             var height = iframe.offsetHeight;
#             iframe.setAttribute('style', 'height:'+ (height+100) +'px');
#         }
#     </script>
#
#     <script
#   src=&quot;https://code.jquery.com/jquery-3.3.1.slim.min.js&quot;
#   integrity=&quot;sha256-3edrmyuQ0w65f8gfBsqowzjJe2iM6n0nKciPUp8y+7E=&quot;
#   crossorigin=&quot;anonymous&quot;></script>
#
#     <!-- code highlight -->
#     <link rel=&quot;stylesheet&quot; type=&quot;text/css&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/styles/vs.min.css&quot; />
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/highlight.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/languages/python.min.js&quot;></script>
#     <!-- <script>hljs.initHighlightingOnLoad();</script> -->
#
#     <!-- Sets the basepath for the library if not in same directory -->
#     <script type='text/javascript'>mxBasePath = './mxgraph/javascript/src'</script>
#     <!-- Loads and initializes the library -->
#     <script type='text/javascript' src='./mxgraph/javascript/src/js/mxClient.js'></script>
#
#     <!-- ELK-JS -->
#     <script type='text/javascript' src='https://cdn.jsdelivr.net/npm/elkjs@0.3.0/lib/elk.bundled.js'></script>
#
#     <!-- import plotting JS -->
#     <script type='text/javascript' src='./src/ui/mxgraphCustom.js'></script>
#     <script type='text/javascript'>
#         main = function(){
#             elkgraph = {'id': 'root', 'label': {'label': '', 'text': ''}, 'children': [{'id': '139859538162016', 'label': {'label': ' | Tank', 'text': ''}, 'children': [{'id': '139859538164144', 'label': {'label': 'empty'}, 'width': 75, 'height': 75, 'cresttype': 'state', 'currentstate': 0}, {'id': '139859538164256', 'label': {'label': 'full'}, 'width': 75, 'height': 75, 'cresttype': 'state', 'currentstate': 0}, {'id': '139859538164312', 'label': {'label': 'partially'}, 'width': 75, 'height': 75, 'cresttype': 'state', 'currentstate': 1}, {'id': '139859538163752', 'label': {'label': 'capacity<br />1.5 (Liters)', 'text': '<h3>capacity</h3><p>1.5 (Liters)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'local'}, {'id': '139859538163920', 'label': {'label': 'maxoutflow<br />0.05 (L/min)', 'text': '<h3>maxoutflow</h3><p>0.05 (L/min)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'local'}, {'id': '139859538164088', 'label': {'label': 'volume<br />1.5 (Liters)', 'text': '<h3>volume</h3><p>1.5 (Liters)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'local'}, {'id': '139859538164424_mid', 'label': {'label': '', 'text': '<h3>to_empty</h3><p>midpoint</p>'}, 'width': 1, 'height': 1, 'cresttype': 'midpoint'}, {'id': '139859538164200_mid', 'label': {'label': '', 'text': '<h3>to_full</h3><p>midpoint</p>'}, 'width': 1, 'height': 1, 'cresttype': 'midpoint'}, {'id': '139859538164368_mid', 'label': {'label': '', 'text': '<h3>to_partially___0</h3><p>midpoint</p>'}, 'width': 1, 'height': 1, 'cresttype': 'midpoint'}, {'id': '139859538164480_mid', 'label': {'label': '', 'text': '<h3>to_partially___1</h3><p>midpoint</p>'}, 'width': 1, 'height': 1, 'cresttype': 'midpoint'}], 'ports': [{'id': '139859538163808', 'label': {'label': 'inflow<br />1 (L/min)', 'text': '<h3>inflow</h3><p>1 (L/min)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'input'}, {'id': '139859538163864', 'label': {'label': 'outflow<br />0 (L/min)', 'text': '<h3>outflow</h3><p>0 (L/min)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'output'}, {'id': '139859538163976', 'label': {'label': 'quantity<br />0 (Liters)', 'text': '<h3>quantity</h3><p>0 (Liters)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'output'}, {'id': '139859538164032', 'label': {'label': 'spill<br />0 (Liters)', 'text': '<h3>spill</h3><p>0 (Liters)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'output'}], 'edges': [{'id': '139859538164424', 'label': {'label': 'to_empty', 'text': '<h3>to_empty</h3><h4>from state partially --> to state empty</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>@transition(source=partially, target=empty)\ndef to_empty(self):\n    return self.volume.value <= 0\n</code></pre>'}, 'sources': ['139859538164312'], 'targets': ['139859538164144'], 'cresttype': 'transition'}, {'id': '139859538164200', 'label': {'label': 'to_full', 'text': '<h3>to_full</h3><h4>from state partially --> to state full</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>@transition(source=partially, target=full)\ndef to_full(self):\n    return self.volume.value >= self.capacity.value\n</code></pre>'}, 'sources': ['139859538164312'], 'targets': ['139859538164256'], 'cresttype': 'transition'}, {'id': '139859538164368', 'label': {'label': 'to_partially___0', 'text': '<h3>to_partially___0</h3><h4>from state empty --> to state partially</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>@transition(source=[empty,full], target=partially)\ndef to_partially(self):\n    return 0 < self.volume.value and self.volume.value < self.capacity.value\n</code></pre>'}, 'sources': ['139859538164144'], 'targets': ['139859538164312'], 'cresttype': 'transition'}, {'id': '139859538164480', 'label': {'label': 'to_partially___1', 'text': '<h3>to_partially___1</h3><h4>from state full --> to state partially</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>@transition(source=[empty,full], target=partially) ...

# %%
class System(Entity):
    
    """ Ports """
    switch = Input(resource=Resources.on_off, value="on")  # turn the pump on / off
    output = Output(resource=Resources.flow, value=0)  # the current outflow of the system
    spill = Output(resource=Resources.water, value=0)  # the amount of water spilt
    quantity = Output(resource=Resources.water, value=0)  # the water that was poured over he plants
    
    """ Subentities """
    pump = Pump()
    tank = Tank()
    
    """ State (no transitions) """
    state = current = State()
    
    """ Influences """
    connect_switch = Influence(source=switch, target=pump.switch)
    connect_pump_to_tank = Influence(source=pump.output, target=tank.inflow)
    connect_output = Influence(source=tank.outflow, target=output)
    connect_spill = Influence(source=tank.spill, target=spill)
    connect_quantity = Influence(source=tank.quantity, target=quantity)
    
sim = Simulator(System())
sim.stabilise()
sim.advance(1)
sim.advance(1.5)
sim.plot()
# Out:
# INFO:simulator.py:Time: 0 | Advancing 0 and stabilising system
# INFO:basesimulator.py:Time: 0 | Firing transition <<off_to_on>> in pump (Pump) : off -> on  | current global time: 0
# INFO:simulator.py:Time: 0 | Port value changed: output (pump) 0 -> 1.5
# INFO:simulator.py:Time: 0 | Port value changed: inflow (tank) 1 -> 1.5
# INFO:simulator.py:Time: 0 | Port value changed: outflow (tank) 0 -> 0.05
# INFO:basesimulator.py:Time: 0 | Firing transition <<to_full>> in tank (Tank) : partially -> full  | current global time: 0
# INFO:simulator.py:Time: 0 | Port value changed: output () 0 -> 0.05
# INFO:simulator.py:Time: 0 | Received instructions to advance 1 time steps. (Current global time: 0)
# INFO:basesimulator.py:There is no behaviour change reachable by time advance.
# INFO:simulator.py:Time: 0 | No next transition
# INFO:simulator.py:Time: 0 | Advancing 1
# INFO:simulator.py:Time: 1 | Advancing 1 and stabilising system
# INFO:simulator.py:Time: 1 | Port value changed: quantity (tank) 0 -> 0.05
# INFO:simulator.py:Time: 1 | Port value changed: spill (tank) 0 -> 1.45
# INFO:simulator.py:Time: 1 | Port value changed: quantity () 0 -> 0.05
# INFO:simulator.py:Time: 1 | Port value changed: spill () 0 -> 1.45
# INFO:simulator.py:Time: 1 | Finished advance and update of system
# INFO:simulator.py:Time: 1 | Received instructions to advance 1.5 time steps. (Current global time: 1)
# INFO:basesimulator.py:There is no behaviour change reachable by time advance.
# INFO:simulator.py:Time: 1 | No next transition
# INFO:simulator.py:Time: 1 | Advancing 1.5
# INFO:simulator.py:Time: 2.5 | Advancing 1.5 and stabilising system
# INFO:simulator.py:Time: 2.5 | Port value changed: quantity (tank) 0.05 -> 0.125
# INFO:simulator.py:Time: 2.5 | Port value changed: spill (tank) 1.45 -> 3.625
# INFO:simulator.py:Time: 2.5 | Port value changed: quantity () 0.05 -> 0.125
# INFO:simulator.py:Time: 2.5 | Port value changed: spill () 1.45 -> 3.625
# INFO:simulator.py:Time: 2.5 | Finished advance and update of system
#     <iframe id="iframe_555b92a2-4915-4161-8028-2310604ca119" style="border:none;" width="100%" height="25px" id="map" srcdoc="
#     <html>
# <head>
#     <!-- CSS Spinning loading dial -->
#     <style>
#         .loader {
#           margin: 16px;
#           border: 16px solid #f3f3f3;
#           border-radius: 50%;
#           border-top: 16px solid blue;
#           border-bottom: 16px solid blue;
#           /* border-right: 32px solid green;
#           border-bottom: 32px solid red;
#           border-left: 32px solid yellow; */
#           width: 64px;
#           height: 64px;
#           -webkit-animation: spin 2s linear infinite;
#           animation: spin 2s linear infinite;
#         }
#
#         @-webkit-keyframes spin {
#           0% { -webkit-transform: rotate(0deg); }
#           100% { -webkit-transform: rotate(360deg); }
#         }
#
#         @keyframes spin {
#           0% { transform: rotate(0deg); }
#           100% { transform: rotate(360deg); }
#         }
#     </style>
#
#     <style>
#         body,html{
#             margin:0px;
#             padding:0px;
#         }
#
#         #growWindow {
#             position: absolute;
#             bottom: 0px;
#             height: 20px;
#             width: 100%;
#             text-align: center;
#             background-color: lightgray;
#             cursor: pointer;
#         }
#
#         i {
#             border: solid black;
#             border-width: 0 3px 3px 0;
#             display: inline-block;
#             padding: 3px;
#         }
#
#         .down {
#             transform: rotate(45deg);
#             -webkit-transform: rotate(45deg);
#         }
#     </style>
#
#     <script>
#         const iframe = window.parent.document.getElementById('iframe_555b92a2-4915-4161-8028-2310604ca119');
#         function growIframe(){
#             var height = iframe.offsetHeight;
#             iframe.setAttribute('style', 'height:'+ (height+100) +'px');
#         }
#     </script>
#
#     <script
#   src=&quot;https://code.jquery.com/jquery-3.3.1.slim.min.js&quot;
#   integrity=&quot;sha256-3edrmyuQ0w65f8gfBsqowzjJe2iM6n0nKciPUp8y+7E=&quot;
#   crossorigin=&quot;anonymous&quot;></script>
#
#     <!-- code highlight -->
#     <link rel=&quot;stylesheet&quot; type=&quot;text/css&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/styles/vs.min.css&quot; />
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/highlight.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/languages/python.min.js&quot;></script>
#     <!-- <script>hljs.initHighlightingOnLoad();</script> -->
#
#     <!-- Sets the basepath for the library if not in same directory -->
#     <script type='text/javascript'>mxBasePath = './mxgraph/javascript/src'</script>
#     <!-- Loads and initializes the library -->
#     <script type='text/javascript' src='./mxgraph/javascript/src/js/mxClient.js'></script>
#
#     <!-- ELK-JS -->
#     <script type='text/javascript' src='https://cdn.jsdelivr.net/npm/elkjs@0.3.0/lib/elk.bundled.js'></script>
#
#     <!-- import plotting JS -->
#     <script type='text/javascript' src='./src/ui/mxgraphCustom.js'></script>
#     <script type='text/javascript'>
#         main = function(){
#             elkgraph = {'id': 'root', 'label': {'label': '', 'text': ''}, 'children': [{'id': '139859537670328', 'label': {'label': '(t = 2.5) | System', 'text': '(t = 2.5)'}, 'children': [{'id': '139859537772672', 'label': {'label': 'state'}, 'width': 75, 'height': 75, 'cresttype': 'state', 'currentstate': 1}, {'id': '139859537773848', 'label': {'label': 'pump | Pump', 'text': 'pump'}, 'children': [{'id': '139859537774016', 'label': {'label': 'off'}, 'width': 75, 'height': 75, 'cresttype': 'state', 'currentstate': 0}, {'id': '139859537773344', 'label': {'label': 'on'}, 'width': 75, 'height': 75, 'cresttype': 'state', 'currentstate': 1}, {'id': '139859537774128_mid', 'label': {'label': '', 'text': '<h3>off_to_on</h3><p>midpoint</p>'}, 'width': 1, 'height': 1, 'cresttype': 'midpoint'}, {'id': '139859537774072_mid', 'label': {'label': '', 'text': '<h3>on_to_off</h3><p>midpoint</p>'}, 'width': 1, 'height': 1, 'cresttype': 'midpoint'}], 'ports': [{'id': '139859537773736', 'label': {'label': 'switch<br />on (switch)', 'text': '<h3>switch</h3><p>on (switch)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'input'}, {'id': '139859537773792', 'label': {'label': 'output<br />1.5 (L/min)', 'text': '<h3>output</h3><p>1.5 (L/min)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'output'}], 'edges': [{'id': '139859537774128', 'label': {'label': 'off_to_on', 'text': '<h3>off_to_on</h3><h4>from state off --> to state on</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>off_to_on = Transition(source=off, target=on, guard=(lambda self: self.switch.value == &quot;on&quot;))\n</code></pre>'}, 'sources': ['139859537774016'], 'targets': ['139859537773344'], 'cresttype': 'transition'}, {'id': '139859537774072', 'label': {'label': 'on_to_off', 'text': '<h3>on_to_off</h3><h4>from state on --> to state off</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>on_to_off = Transition(source=on, target=off, guard=(lambda self: self.switch.value == &quot;off&quot;))\n</code></pre>'}, 'sources': ['139859537773344'], 'targets': ['139859537774016'], 'cresttype': 'transition'}, {'id': '139859537774240', 'label': {'label': 'set_off', 'text': '<h3>set_off</h3><h4>state off --> writes port pump.output</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>@update(state=off, target=output)\ndef set_off(self, dt=0):\n    return 0\n</code></pre>'}, 'sources': ['139859537774016'], 'targets': ['139859537773792'], 'cresttype': 'update'}, {'id': '139859537774184', 'label': {'label': 'set_on', 'text': '<h3>set_on</h3><h4>state on --> writes port pump.output</h4>', 'code': '<pre style=&quot;font-size:1.2em;&quot;><code class=&quot;python&quot;>@update(state=on, target=output)\ndef set_on(self, dt=0):\n    return 1.5\n</code></pre>'}, 'sources': ['139859537773344'], 'targets': ['139859537773792'], 'cresttype': 'update'}], 'cresttype': 'entity', 'width': 300, 'height': 200}, {'id': '139859537773288', 'label': {'label': 'tank | Tank', 'text': 'tank'}, 'children': [{'id': '139859537774800', 'label': {'label': 'empty'}, 'width': 75, 'height': 75, 'cresttype': 'state', 'currentstate': 0}, {'id': '139859537774688', 'label': {'label': 'full'}, 'width': 75, 'height': 75, 'cresttype': 'state', 'currentstate': 1}, {'id': '139859537774632', 'label': {'label': 'partially'}, 'width': 75, 'height': 75, 'cresttype': 'state', 'currentstate': 0}, {'id': '139859537774408', 'label': {'label': 'capacity<br />1.5 (Liters)', 'text': '<h3>capacity</h3><p>1.5 (Liters)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'local'}, {'id': '139859537773680', 'label': {'label': 'maxoutflow<br />0.05 (L/min)', 'text': '<h3>maxoutflow</h3><p>0.05 (L/min)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'local'}, {'id': '139859537773512', 'label': {'label': 'volume<br />1.5 (Liters)', 'text': '<h3>volume</h3><p>1.5 (Liters)</p>'}, 'width': 75, 'height': 30, 'cresttype': 'local'}, {'id': '139859537774968_mid', 'lab ...
